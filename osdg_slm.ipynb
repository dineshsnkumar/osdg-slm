# %% [markdown]
# <a href="https://colab.research.google.com/github/dineshsnkumar/osdg-slm/blob/main/osdg_slm.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import os
os.environ["KERAS_BACKEND"] = "jax"

import keras
import pandas as pd
import tensorflow as tf

keras.utils.set_random_seed(812)

# %%
splits = {'train': '2022-04-01/train-00000-of-00001.parquet', 'test': '2022-04-01/test-00000-of-00001.parquet'}
df = pd.read_parquet("hf://datasets/albertmartinez/OSDG/" + splits["train"])

# %%
df
# Out:
#                                                     text  labels
# 0      Moving forward, it is therefore essential that...       6
# 1      Also needed are productivity improvements alon...       1
# 2      Outside Asia, the Middle East experiences the ...       6
# 3      The largest deposit is at Tkibuli (268 million...       6
# 4      This standard represents the target for energy...      11
# ...                                                  ...     ...
# 22623  Since doctors and nurses receive relatively hi...       7
# 22624  This sector has, in what concerns hydropower, ...       5
# 22625  E-health services evolve to satisfy those inte...       2
# 22626  In addition, informal recyclers who search the...      11
# 22627  For instance, local farmers and communities ha...       1
#
# [22628 rows x 2 columns]
